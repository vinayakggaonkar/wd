# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
deli = pd.read_csv('deliveries.csv')

# %%
match = pd.read_csv('matches.csv')

# %%
match
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
deli
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
# we need the data in a different form

# %%
# from out curremt data set we need to extract the following columns
# batting team , bowling team , city , runs , balls left, wickets left , total runs, crr, rrr results

# %%
deli.groupby(['match_id','inning']).sum()['total_runs']
# Out:
# match_id  inning
# 1         1         207
#           2         172
# 2         1         184
#           2         187
# 3         1         183
#                    ...
# 11413     2         170
# 11414     1         155
#           2         162
# 11415     1         152
#           2         157
# Name: total_runs, Length: 1528, dtype: int64

# %%
total_score_df = deli.groupby(['match_id','inning']).sum()['total_runs'].reset_index()

# %%
total_score_df
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 1            1       2         172
# 2            2       1         184
# 3            2       2         187
# 4            3       1         183
# ...        ...     ...         ...
# 1523     11413       2         170
# 1524     11414       1         155
# 1525     11414       2         162
# 1526     11415       1         152
# 1527     11415       2         157
#
# [1528 rows x 3 columns]

# %%
# since we want only 1st innings total runs, so we will drop the total scores of the 
# second innings

# %%
total_score_df = total_score_df[total_score_df['inning'] == 1]
# we will take the total runs of the 1st innings

# %%
total_score_df
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 2            2       1         184
# 4            3       1         183
# 6            4       1         163
# 8            5       1         157
# ...        ...     ...         ...
# 1518     11347       1         143
# 1520     11412       1         136
# 1522     11413       1         171
# 1524     11414       1         155
# 1526     11415       1         152
#
# [756 rows x 3 columns]

# %%
# now merge the total_score_df into the match data

# %%
# the common columns in total_score_df and match is match_id in total_score_df and 'id' in match

# %%
match_df = match.merge(total_score_df[['match_id','total_runs']], left_on='id', right_on='match_id')
# here left on and right on are the joining conditions
# innings is not required as both the team has 1 inning

# %%
match_df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
# we are now gonna drop the data of the teams that are not playing right now

# %%
match_df['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
teams = ['Sunrisers Hyderabad', 'Mumbai Indians'
       , 'Royal Challengers Bangalore',
       'Kolkata Knight Riders',  'Kings XI Punjab',
       'Chennai Super Kings', 'Rajasthan Royals',
       'Delhi Capitals']

# %%
match_df['team1'] = match_df['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match_df['team2'] = match_df['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

match_df['team1'] = match_df['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['team2'] = match_df['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
# we are taking team1 and team 2 cuz there are two columns

# %%
match_df= match_df[match_df['team1'].isin(teams)]
match_df= match_df[match_df['team2'].isin(teams)]
# in team1 column keep the teams that are present in the teams variable
# in team2 column keep the teams that are present in the teams variable

# %%
match_df.shape
# Out:
# (641, 20)

# %%
match_df['dl_applied'].value_counts()
# there are only 10 matches in which rain came
# so i dont need that 10 matches, so we will drop the matches with rain =0 and keep the matches with rain = 1
# Out:
# dl_applied
# 0    626
# 1     15
# Name: count, dtype: int64

# %%
match_df= match_df[match_df['dl_applied']==0]

# %%
match_df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# 6        7  IPL-2017         Mumbai  09-04-2017        Kolkata Knight Riders
# 7        8  IPL-2017         Indore  10-04-2017  Royal Challengers Bangalore
# 9       10  IPL-2017         Mumbai  12-04-2017          Sunrisers Hyderabad
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
match_df = match_df[['match_id','city','winner','total_runs']]

# %%
match_df
# Out:
#      match_id           city                       winner  total_runs
# 0           1      Hyderabad          Sunrisers Hyderabad         207
# 4           5      Bangalore  Royal Challengers Bangalore         157
# 6           7         Mumbai               Mumbai Indians         178
# 7           8         Indore              Kings XI Punjab         148
# 9          10         Mumbai               Mumbai Indians         158
# ..        ...            ...                          ...         ...
# 751     11347         Mumbai               Mumbai Indians         143
# 752     11412        Chennai               Mumbai Indians         136
# 753     11413  Visakhapatnam               Delhi Capitals         171
# 754     11414  Visakhapatnam          Chennai Super Kings         155
# 755     11415      Hyderabad               Mumbai Indians         152
#
# [626 rows x 4 columns]

# %%
deli_df = match_df.merge(deli, on='match_id')

# %%
deli_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 0              1  Hyderabad  Sunrisers Hyderabad           207       1
# 1              1  Hyderabad  Sunrisers Hyderabad           207       1
# 2              1  Hyderabad  Sunrisers Hyderabad           207       1
# 3              1  Hyderabad  Sunrisers Hyderabad           207       1
# 4              1  Hyderabad  Sunrisers Hyderabad           207       1
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           152       2
# 149574     11415  Hyderabad       Mumbai Indians           152       2
# 149575     11415  Hyderabad       Mumbai Indians           152       2
# 149576     11415  Hyderabad       Mumbai Indians           152       2
# 149577     11415  Hyderabad       Mumbai Indians           152       2
#
#                batting_team                 bowling_team  over  ball  \
# ...

# %%
# i need the data of the 2nd innings thats chasing the total runs

# %%
deli_df = deli_df[deli_df['inning']==2]

# %%
deli_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           152       2
# 149574     11415  Hyderabad       Mumbai Indians           152       2
# 149575     11415  Hyderabad       Mumbai Indians           152       2
# 149576     11415  Hyderabad       Mumbai Indians           152       2
# 149577     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
deli_df.shape
# Out:
# (72413, 24)

# %%
# now i need runs left, balls left, wickets lef, crr ,rrrand results

# %%
# now we want to check the runs per each ball, for that there is a column called as total_runs_y
# tis gives the total runs per ball

# %%
deli_df.isnull().sum()
# Out:
# match_id                0
# city                  832
# winner                 27
# total_runs_x            0
# inning                  0
# batting_team            0
# bowling_team            0
# over                    0
# ball                    0
# batsman                 0
# non_striker             0
# bowler                  0
# is_super_over           0
# wide_runs               0
# bye_runs                0
# legbye_runs             0
# noball_runs             0
# penalty_runs            0
# batsman_runs            0
# extra_runs              0
# total_runs_y            0
# player_dismissed    68860
# dismissal_kind      68860
# fielder             69855
# dtype: int64

# %%
deli_df['current_score'] = deli_df.groupby('match_id')['total_runs_y'].cumsum()
# Out:
# C:\Users\sindh\AppData\Local\Temp\ipykernel_16044\3957963066.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deli_df['current_score'] = deli_df.groupby('match_id')['total_runs_y'].cumsum()

# %%
deli_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           152       2
# 149574     11415  Hyderabad       Mumbai Indians           152       2
# 149575     11415  Hyderabad       Mumbai Indians           152       2
# 149576     11415  Hyderabad       Mumbai Indians           152       2
# 149577     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %% [markdown]
# # runs left

# %%
deli_df['runs_left'] = deli_df['total_runs_x'] - deli_df['current_score']
# Out:
# C:\Users\sindh\AppData\Local\Temp\ipykernel_16044\3839752454.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deli_df['runs_left'] = deli_df['total_runs_x'] - deli_df['current_score']

# %%
deli_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           152       2
# 149574     11415  Hyderabad       Mumbai Indians           152       2
# 149575     11415  Hyderabad       Mumbai Indians           152       2
# 149576     11415  Hyderabad       Mumbai Indians           152       2
# 149577     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %% [markdown]
# # balls left

# %%
deli_df['balls_left'] = 126 - (deli_df['over']*6 + deli_df['ball'])
# Out:
# C:\Users\sindh\AppData\Local\Temp\ipykernel_16044\614271809.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deli_df['balls_left'] = 126 - (deli_df['over']*6 + deli_df['ball'])

# %%
deli_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           152       2
# 149574     11415  Hyderabad       Mumbai Indians           152       2
# 149575     11415  Hyderabad       Mumbai Indians           152       2
# 149576     11415  Hyderabad       Mumbai Indians           152       2
# 149577     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %% [markdown]
# # wickets left

# %%
# NaN - there is no person out

# %%
deli_df['player_dismissed'] = deli_df['player_dismissed'].fillna("0")
# Out:
# C:\Users\sindh\AppData\Local\Temp\ipykernel_16044\2365413995.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deli_df['player_dismissed'] = deli_df['player_dismissed'].fillna("0")

# %%
deli_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           152       2
# 149574     11415  Hyderabad       Mumbai Indians           152       2
# 149575     11415  Hyderabad       Mumbai Indians           152       2
# 149576     11415  Hyderabad       Mumbai Indians           152       2
# 149577     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
deli_df['player_dismissed'] = deli_df['player_dismissed'].apply(lambda x:x if x=="0" else '1')
# Out:
# C:\Users\sindh\AppData\Local\Temp\ipykernel_16044\353024169.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deli_df['player_dismissed'] = deli_df['player_dismissed'].apply(lambda x:x if x=="0" else '1')

# %%
deli_df['player_dismissed'] = deli_df['player_dismissed'].astype('int')
# Out:
# C:\Users\sindh\AppData\Local\Temp\ipykernel_16044\3560607413.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deli_df['player_dismissed'] = deli_df['player_dismissed'].astype('int')

# %%
wickets = deli_df.groupby('match_id')['player_dismissed'].cumsum()

# %%
deli_df['wickets'] = 10 - wickets
# Out:
# C:\Users\sindh\AppData\Local\Temp\ipykernel_16044\533091454.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deli_df['wickets'] = 10 - wickets

# %%
'''deli_df['player_dismissed'] = deli_df['player_dismissed'].fillna("0")
deli_df['player_dismissed'] = deli_df['player_dismissed'].apply(lambda x:x if x=="0" else '1')
deli_df['player_dismissed'] = deli_df['player_dismissed'].astype('int')
wickets = deli_df.groupby('match_id')['player_dismissed'].cumsum()
deli_df['wickets'] = 10 - wickets
deli_df'''
# Out:
# 'deli_df[\'player_dismissed\'] = deli_df[\'player_dismissed\'].fillna("0")\ndeli_df[\'player_dismissed\'] = deli_df[\'player_dismissed\'].apply(lambda x:x if x=="0" else \'1\')\ndeli_df[\'player_dismissed\'] = deli_df[\'player_dismissed\'].astype(\'int\')\ndeli_df[\'wickets\'] = deli_df.groupby(\'match_id\')[\'player_dismissed\'].cumsum()\ndeli_df[\'wickets\'] = 10 - wickets\ndeli_df'

# %%
deli_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           152       2
# 149574     11415  Hyderabad       Mumbai Indians           152       2
# 149575     11415  Hyderabad       Mumbai Indians           152       2
# 149576     11415  Hyderabad       Mumbai Indians           152       2
# 149577     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %% [markdown]
#  # cnn

# %%
# crr = runs/overs

# %%
deli_df['crr'] = (deli_df['current_score']*6)/(120 - deli_df['balls_left'])
# Out:
# C:\Users\sindh\AppData\Local\Temp\ipykernel_16044\3928788073.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deli_df['crr'] = (deli_df['current_score']*6)/(120 - deli_df['balls_left'])

# %%
deli_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... extra_runs total_runs_y  player_dismissed  \
# 125       CH Gayle  ...          0            1                 0
# ...

# %%
deli_df['rrr'] = (deli_df['runs_left']*6)/deli_df['balls_left']
# Out:
# C:\Users\sindh\AppData\Local\Temp\ipykernel_16044\30609310.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deli_df['rrr'] = (deli_df['runs_left']*6)/deli_df['balls_left']

# %%
deli_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           152       2
# 149574     11415  Hyderabad       Mumbai Indians           152       2
# 149575     11415  Hyderabad       Mumbai Indians           152       2
# 149576     11415  Hyderabad       Mumbai Indians           152       2
# 149577     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %% [markdown]
# # result

# %%
# to check result
# for every row check the winning team with the batting team, if they are same then the result is 1
# if not then the result is 0

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner']else 0

# %%
deli_df['result'] = deli_df.apply(result, axis=1)
# Out:
# C:\Users\sindh\AppData\Local\Temp\ipykernel_16044\101793525.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deli_df['result'] = deli_df.apply(result, axis=1)

# %%
deli_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           152       2
# 149574     11415  Hyderabad       Mumbai Indians           152       2
# 149575     11415  Hyderabad       Mumbai Indians           152       2
# 149576     11415  Hyderabad       Mumbai Indians           152       2
# 149577     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
final_df = deli_df[['batting_team','bowling_team','city','runs_left','balls_left','wickets','total_runs_x','crr','rrr','result']]

# %%
final_df
# Out:
#                        batting_team         bowling_team       city  \
# 125     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 126     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 127     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 128     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 129     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# ...                             ...                  ...        ...
# 149573          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149574          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149575          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149576          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149577          Chennai Super Kings       Mumbai Indians  Hyderabad
#
#         runs_left  balls_left  wickets  total_runs_x       crr        rrr  \
# 125           206         119       10           207  6.000000  10.386555
# ...

# %%
# now we will shuffle it, as all the balls are in one below each other
#so they might be biased

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#                  batting_team                 bowling_team     city  \
# 22084         Kings XI Punjab  Royal Challengers Bangalore   Durban
# 136690        Kings XI Punjab        Kolkata Knight Riders  Kolkata
# 44901     Chennai Super Kings        Kolkata Knight Riders  Chennai
# 56598        Rajasthan Royals               Mumbai Indians   Mumbai
# 66464         Deccan Chargers          Chennai Super Kings  Chennai
# ...                       ...                          ...      ...
# 138859    Chennai Super Kings               Mumbai Indians   Mumbai
# 146082       Rajasthan Royals          Sunrisers Hyderabad   Jaipur
# 95840   Kolkata Knight Riders               Mumbai Indians  Cuttack
# 20188        Rajasthan Royals          Chennai Super Kings   Mumbai
# 42721        Delhi Daredevils        Kolkata Knight Riders  Kolkata
#
#         runs_left  balls_left  wickets  total_runs_x        crr        rrr  \
# ...

# %%
final_df.sample()
# Out:
#                batting_team    bowling_team       city  runs_left  balls_left  \
# 149501  Chennai Super Kings  Mumbai Indians  Hyderabad         91          74
#
#         wickets  total_runs_x       crr       rrr  result
# 149501        9           152  7.956522  7.378378       0

# %%
final_df.isnull().sum()
# Out:
# batting_team      0
# bowling_team      0
# city            832
# runs_left         0
# balls_left        0
# wickets           0
# total_runs_x      0
# crr               0
# rrr               7
# result            0
# dtype: int64

# %%
# since there were many NaN values, so we droped them
final_df.dropna(inplace=True)

# %%
# there were many rows in which the rrr was coming infinite, so to avoid that
# we are considering only the rows whose ball left are not zero
final_df = final_df[final_df['balls_left'] != 0]

# %% [markdown]
# # model building

# %%
X = final_df.iloc[:,:-1]
y = final_df.iloc[:,-1]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=1)

# %%
X_train
# Out:
#                  batting_team                 bowling_team       city  \
# 65678   Kolkata Knight Riders          Chennai Super Kings    Chennai
# 111814       Delhi Daredevils          Chennai Super Kings     Raipur
# 126701    Chennai Super Kings  Royal Challengers Bangalore  Bengaluru
# 65228        Rajasthan Royals             Delhi Daredevils      Delhi
# 51290     Chennai Super Kings               Mumbai Indians     Mumbai
# ...                       ...                          ...        ...
# 117112         Mumbai Indians        Kolkata Knight Riders     Mumbai
# 110366         Mumbai Indians          Chennai Super Kings    Chennai
# 128008  Kolkata Knight Riders  Royal Challengers Bangalore  Bengaluru
# 76636     Sunrisers Hyderabad              Kings XI Punjab  Hyderabad
# 33551         Deccan Chargers        Kolkata Knight Riders     Mumbai
#
#         runs_left  balls_left  wickets  total_runs_x       crr        rrr
# ...

# %%
#since our batting team, bowling team and city are categorical data
# we need to do one hot encoding to make it a numerical data

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf =ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False, drop='first'),['batting_team','bowling_team','city'])
],remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(X_train, y_train)
# Out:
# C:\Users\sindh\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred = pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# this is for logistics regression
# Out:
# 0.8001261475926834

# %%
pd.crosstab(y_test,y_pred)
# Out:
# col_0      0     1
# result
# 0       5243  1480
# 1       1372  6174

# %%
# for random forest
from sklearn.ensemble import RandomForestClassifier

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',RandomForestClassifier())
])

# %%
pipe.fit(X_train, y_train)
# Out:
# C:\Users\sindh\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', RandomForestClassifier())])

# %%
y_pred = pipe.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9990889340528418

# %%
pd.crosstab(y_test,y_pred)
# Out:
# col_0      0     1
# result
# 0       6714     9
# 1          4  7542

# %%
pipe.predict_proba(X_test)[0]
# Out:
# array([1., 0.])

# %%
pipe.predict_proba(X_test)[3]
# Out:
# array([0., 1.])

# %%
pipe.predict_proba(X_test)[4]
# Out:
# array([1., 0.])

# %%
pipe.predict_proba(X_test)[6]
# Out:
# array([0.15, 0.85])

# %%
# in random forest it is actually biased towards to one team
#for showing probabilities, logistics regression is good

# %%
# we have to once again train the logistics regression model
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)

accuracy_score(y_test, y_pred)
# Out:
# C:\Users\sindh\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# 0.8001261475926834

# %%
pipe.predict_proba(X_test)[0]
# Out:
# array([0.77739781, 0.22260219])

# %%
pipe.predict_proba(X_test)[5]
# Out:
# array([0.96797102, 0.03202898])

# %%
pipe.predict_proba(X_test)[7]
# Out:
# array([0.33856712, 0.66143288])

# %%
#the logistics regression is showing more realistic probability

# %%
def match_progression(x_df,match_id,pipe):
    match = x_df[x_df['match_id'] == match_id]
    match = match[(match['ball'] == 6)]
    temp_df = match[['batting_team','bowling_team','city','runs_left','balls_left','wickets','total_runs_x','crr','rrr']]
    temp_df = temp_df[temp_df['balls_left'] != 0]
    result = pipe.predict_proba(temp_df)
    temp_df['lose'] = np.round(result.T[0]*100,1)
    temp_df['win'] = np.round(result.T[1]*100,1)
    temp_df['end_of_over'] = range(1,temp_df.shape[0]+1)
    
    target = temp_df['total_runs_x'].values[0]
    runs = list(temp_df['runs_left'].values)
    new_runs = runs[:]
    runs.insert(0,target)
    temp_df['runs_after_over'] = np.array(runs)[:-1] - np.array(new_runs)
    wickets = list(temp_df['wickets'].values)
    new_wickets = wickets[:]
    new_wickets.insert(0,10)
    wickets.append(0)
    w = np.array(wickets)
    nw = np.array(new_wickets)
    temp_df['wickets_in_over'] = (nw - w)[0:temp_df.shape[0]]
    
    print("target=",target)
    temp_df = temp_df[['end_of_over','runs_after_over','wickets_in_over','lose','win']]
    return temp_df,target

# %%
temp_df, target = match_progression(deli_df,1,pipe)
temp_df
# Out:
# target= 207
#      end_of_over  runs_after_over  wickets_in_over  lose   win
# 130            1               11                0  88.9  11.1
# 136            2                1                0  92.0   8.0
# 142            3               16                0  84.7  15.3
# 148            4               11                0  79.4  20.6
# 155            5                5                0  79.8  20.2
# 162            6               10                1  84.8  15.2
# 168            7                7                1  90.5   9.5
# 174            8               13                0  85.4  14.6
# 180            9               10                0  81.3  18.7
# 187           10               10                0  76.4  23.6
# 194           11               16                0  62.2  37.8
# 201           12                8                1  72.6  27.4
# 207           13                8                1  81.1  18.9
# 213           14                4                1  90.1   9.9
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(18,8))
plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over'],color='yellow',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['win'],color='green',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
plt.bar(temp_df['end_of_over'],temp_df['runs_after_over'])
plt.title('Target-' + str(target))
# Out:
# Text(0.5, 1.0, 'Target-207')

# %%
plt.figure(figsize=(18,8))
plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over'],color='yellow',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['win'],color='green',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
plt.bar(temp_df['end_of_over'],temp_df['runs_after_over'])
plt.title('Target-' + str(target))
# Out:
# target= 182
#       end_of_over  runs_after_over  wickets_in_over  lose   win
# 9298            1                2                0  72.8  27.2
# 9304            2               12                0  61.0  39.0
# 9311            3                4                2  86.0  14.0
# 9317            4                3                0  87.6  12.4
# 9324            5               13                0  80.9  19.1
# 9330            6                5                0  81.1  18.9
# 9336            7                6                0  80.3  19.7
# 9343            8               15                0  68.5  31.5
# 9350            9                5                1  80.8  19.2
# 9356           10                2                1  90.8   9.2
# 9362           11                1                0  92.9   7.1
# 9368           12               22                0  81.8  18.2
# 9374           13                4                1  90.4   9.6
# ...

# %%
plt.figure(figsize=(18,8))
plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over'],color='yellow',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['win'],color='green',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
plt.bar(temp_df['end_of_over'],temp_df['runs_after_over'])
plt.title('Target-' + str(target))
# Out:
# Text(0.5, 1.0, 'Target-182')

# %%
temp_df, target = match_progression(deli_df,74,pipe)
temp_df
# Out:
# target= 178
#        end_of_over  runs_after_over  wickets_in_over  lose   win
# 10459            1                4                0  57.7  42.3
# 10467            2                8                0  52.0  48.0
# 10473            3                1                0  59.0  41.0
# 10479            4                7                1  70.5  29.5
# 10485            5               12                0  60.3  39.7
# 10491            6               13                0  47.9  52.1
# 10497            7                9                0  41.9  58.1
# 10505            8               15                0  27.8  72.2
# 10511            9                7                0  25.6  74.4
# 10518           10               17                0  14.0  86.0
# 10524           11                9                1  19.5  80.5
# 10530           12                9                0  16.0  84.0
# 10536           13                8                0  13.8  86.2
# ...

# %%
plt.figure(figsize=(18,8))
plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over'],color='yellow',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['win'],color='green',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
plt.bar(temp_df['end_of_over'],temp_df['runs_after_over'])
plt.title('Target-' + str(target))
# Out:
# Text(0.5, 1.0, 'Target-178')

# %%
temp_df, target = match_progression(deli_df,204,pipe)
temp_df
# Out:
# target= 181
#        end_of_over  runs_after_over  wickets_in_over  lose   win
# 40503            1               13                0  72.4  27.6
# 40510            2               10                0  66.8  33.2
# 40517            3                9                1  75.4  24.6
# 40523            4                9                0  70.9  29.1
# 40529            5                5                0  71.5  28.5
# 40535            6               13                0  60.4  39.6
# 40541            7                6                0  59.3  40.7
# 40548            8               10                0  51.9  48.1
# 40554            9                3                1  70.3  29.7
# 40560           10                9                0  65.1  34.9
# 40566           11                6                0  64.0  36.0
# 40572           12                5                0  64.6  35.4
# 40578           13                9                0  59.1  40.9
# ...

# %%
plt.figure(figsize=(18,8))
plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over'],color='yellow',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['win'],color='green',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
plt.bar(temp_df['end_of_over'],temp_df['runs_after_over'])
plt.title('Target-' + str(target))
# Out:
# Text(0.5, 1.0, 'Target-181')
